# %% [markdown]
# This notebook uses the Kaggle titanic dataset. The objective is to classify survivors and non-survivors on the titanic using some part of the data, and use the remaining data to test how well we are able to predict.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix
from sklearn import datasets, neighbors, linear_model, preprocessing
from sklearn.model_selection import learning_curve, ShuffleSplit

# %%
#This function came from http://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html#sphx-glr-auto-examples-model-selection-plot-learning-curve-py

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# The titanic dataset from kaggle. Import using pandas. variable "data" is now a pandas dataframe

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Trying to explore the data a little bit.
# - what columns does it have?
# - what kind of data does each column contain?
# - are there any columns of string type?
# - are there missing entries?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Deleting columns that are not helpful for classifying in this example - Cabin, Name, Ticket

# %%
data.drop({"Cabin", "Name", "Ticket"}, axis = 1, inplace = True)

# %%
data.isnull().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.7+ KB

# %% [markdown]
# Need to fix up the
# 1. age column because 100+ missing entries.
# 2. embarked - 2 missing entries
# 3. gender and embarked - categorical columns in text. Convert to one hot encoding.

# %%
sns.barplot(x = "Embarked", y = "Survived", data = data)
plt.show()

# %% [markdown]
# copying data into another variable dataclean. We will store cleaned up data here.

# %%
dataclean = data

# %% [markdown]
# Since "Embarked" has only 2 missing entries, we might fill it up with the most common choice. Clearly, S is the most common choice.

# %%
data.groupby('Survived').Embarked.value_counts()
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           219
#           C            93
#           Q            30
# Name: Embarked, dtype: int64

# %%
data["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# Since the most common embarked value is "S", we will fill this in the missing rows.

# %%
data.fillna(value = {"Embarked" : "S"}, inplace = True).head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# To get a sense of what are the most important features, let us look at the heat map.
# The most important variable for predicting who survived in the titanic should have a high correlation with the column survived => absolute value closer to 1 rather than 0.

# %%
#pd.get_dummies(data[{"Sex", "Embarked"}])
dataclean = pd.get_dummies(dataclean, columns={"Sex", "Embarked"}, drop_first=True)
dataclean["Age"].describe()
dataclean.fillna(value = {"Age":29.699118}, inplace = True)
print(dataclean.columns)
print(dataclean.info())

# %%
sns.heatmap(dataclean.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# Based on the above, the important variables seem to be
# - sex
# - embarked
# - fare
# - Pclass

# %%
dataclean.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Embarked_Q  Embarked_S    Sex_male
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.086420    0.725028    0.647587
# std      0.806057   49.693429    0.281141    0.446751    0.477990
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# Now the data is cleaned up enough to apply a classifier using scikitlearn.
# First we will split the data into train and test sets.
#
# To begin with, we will apply logistic regression.

# %%
train,test=train_test_split(dataclean,test_size = 0.3, random_state=0,stratify=dataclean['Survived'])

# %%
X_train = train.drop("Survived", axis=1)
y_train = train["Survived"]
X_test = test.drop("Survived", axis = 1)
y_test = test["Survived"]
X_train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   623.000000  623.000000  623.000000  623.000000  623.000000
# mean    443.274478    2.290530   29.561329    0.516854    0.365971
# std     260.820435    0.841464   12.852244    1.075579    0.763473
# min       2.000000    1.000000    0.420000    0.000000    0.000000
# 25%     216.000000    1.500000   22.000000    0.000000    0.000000
# 50%     440.000000    3.000000   29.699118    0.000000    0.000000
# 75%     672.500000    3.000000   35.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    5.000000
#
#              Fare  Embarked_Q  Embarked_S    Sex_male
# count  623.000000  623.000000  623.000000  623.000000
# mean    33.678424    0.080257    0.733547    0.648475
# std     54.108168    0.271909    0.442459    0.477830
# min      0.000000    0.000000    0.000000    0.000000
# 25%      7.925000    0.000000    0.000000    0.000000
# ...

# %%
logistic = LogisticRegression()
fit = logistic.fit(X_train, y_train)
fit.score(X_test, y_test)
# Out:
# 0.81343283582089554

# %% [markdown]
# We are able to predict on the test data correctly 81% of the time! But, there's a catch. The mean of "Survived" is 0.38, meaning that only about 38% of the people survived. Even if we predicted everyone was dead, we would be right 62% of the time! We need to look more carefull at false positives and true negatives.
#
# For this, we will use a confusion matrix. Then extract precision, recall and f1-score parameters. An objective of our classifier is to get a high accuracy on the test set, and a high f1-score.

# %%
sns.heatmap(confusion_matrix(y_test, logistic.predict(X_test)),annot=True,fmt='2.0f')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test, logistic.predict(X_test)).ravel()
precision = tp/(tp+fp)
recall = tp/(tp+fn)
fscore = 2*precision*recall/(precision+recall)
from sklearn.metrics import classification_report
print(classification_report(y_test, logistic.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.90      0.86       165
#           1       0.81      0.67      0.73       103
#
# avg / total       0.81      0.81      0.81       268
# C:\Users\Astha\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: divide by zero encountered in long_scalars

# %% [markdown]
# Keeping with the model, we will try to increase accuracy by doing 2 things:
# - normalization
# - tuning the C parameter (regularization).

# %%
normalized_data=(dataclean-dataclean.min())/(dataclean.max()-dataclean.min())
#normalized_data.describe()
train,test=train_test_split(normalized_data,test_size = 0.3, random_state=0,stratify=normalized_data['Survived'])
X_train = train.drop("Survived", axis=1)
y_train = train["Survived"]
X_test = test.drop("Survived", axis = 1)
y_test = test["Survived"]
X_train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   623.000000  623.000000  623.000000  623.000000  623.000000
# mean      0.496938    0.645265    0.366189    0.064607    0.060995
# std       0.293057    0.420732    0.161501    0.134447    0.127246
# min       0.001124    0.000000    0.000000    0.000000    0.000000
# 25%       0.241573    0.250000    0.271174    0.000000    0.000000
# 50%       0.493258    1.000000    0.367921    0.000000    0.000000
# 75%       0.754494    1.000000    0.434531    0.125000    0.000000
# max       1.000000    1.000000    1.000000    1.000000    0.833333
#
#              Fare  Embarked_Q  Embarked_S    Sex_male
# count  623.000000  623.000000  623.000000  623.000000
# mean     0.065736    0.080257    0.733547    0.648475
# std      0.105612    0.271909    0.442459    0.477830
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.015469    0.000000    0.000000    0.000000
# ...

# %%
logistic_reg = LogisticRegression(C = 1)
fit = logistic_reg.fit(X_train, y_train)
print(fit.score(X_test, y_test))
sns.heatmap(confusion_matrix(y_test, logistic_reg.predict(X_test)),annot=True,fmt='2.0f')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
print(classification_report(y_test, logistic_reg.predict(X_test)))
# Out:
# 0.813432835821
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.88      0.85       165
#         1.0       0.79      0.70      0.74       103
#
# avg / total       0.81      0.81      0.81       268

# %%
logistic_reg = LogisticRegression(C = 100)
fit = logistic_reg.fit(X_train, y_train)
print(fit.score(X_test, y_test))
sns.heatmap(confusion_matrix(y_test, logistic_reg.predict(X_test)),annot=True,fmt='2.0f')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
print(classification_report(y_test, logistic_reg.predict(X_test)))
# Out:
# 0.805970149254
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.88      0.85       165
#         1.0       0.79      0.68      0.73       103
#
# avg / total       0.80      0.81      0.80       268

# %% [markdown]
# Unofortunately, we got no improvement in the performance by normalization, and a drop in the fit accuracy with C = 100 (vs. default value of 1). We did get a marginal increase in the f score for survivors (from 0.73 to 0.74) by normalization, keeping C = 1. Let's try C = 0.01 as well. Based on all 3, C = 1 is the best value for fit accuracy and f-score.

# %%
logistic_reg = LogisticRegression(C = 100)
fit = logistic_reg.fit(X_train, y_train)
print(fit.score(X_test, y_test))
sns.heatmap(confusion_matrix(y_test, logistic_reg.predict(X_test)),annot=True,fmt='2.0f')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
print(classification_report(y_test, logistic_reg.predict(X_test)))
# Out:
# 0.805970149254
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.88      0.85       165
#         1.0       0.79      0.68      0.73       103
#
# avg / total       0.80      0.81      0.80       268

# %% [markdown]
# Let's plot a learning curve for this dataset to find out if having more data would have helped us get a higher accuracy with this model.

# %%
X = normalized_data.drop("Survived", axis=1)
y = normalized_data["Survived"]
train_sizes, train_scores, test_scores = learning_curve(logistic_reg, X, y, cv=None, n_jobs=1, train_sizes=[ 0.1, 0.33, 0.55, 0.78, 1.])

# %%
plot = plot_learning_curve(logistic_reg, "learning curve", X, y, train_sizes=np.linspace(.1, 1.0, 10))
plt.show()

# %% [markdown]
# The plot looks a bit noisy. Let's replot it by trying out several splits of train and test (cross validation) sets.

# %%
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
title = "Learning Curve"
estimator = LogisticRegression(C = 100)
plot_learning_curve(estimator, title, X, y, cv=cv, n_jobs=4)
plt.show()

# %% [markdown]
# Since both the cross validation and test set seem to approach the same value, we have an optimum variance. Since the values are asymptoting, more data wouldn't have helped us make a better estimate with this model.

# %% [markdown]
# Let's try to visualize this data in 2D. We will attempt by first find 2 principal components using Principal components analysis (PCA).

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
xnew = pca.fit_transform(X)

# %%
print('Variance PCA: {}'.format(np.sum(pca.explained_variance_ratio_)))
# Out:
# Variance PCA: 0.9249727124

# %%
xnew[:,1].shape
# Out:
# (891L,)

# %%
plt.scatter(xnew[:,0], xnew[:,1], c = 0.5*y, cmap = 'rainbow')
plt.show()

# %% [markdown]
# While PCA tells us that these are the 2 principal components, plotting in these components did not fetch up clear, separate groups of data. Lets try Teesni instead.

# %%
plt.scatter(X["Sex_male"], X["Pclass"], c = y, cmap = 'rainbow')
plt.xlabel('Sex_male')
plt.ylabel('Pclass')
plt.show()

# %%
from sklearn.manifold import TSNE
#Run T-SNE on the PCA features.
tsne = TSNE(n_components=2, verbose = 1)
tsne_results = tsne.fit_transform(X,y)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 891 / 891
# [t-SNE] Mean sigma: 0.148857
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 0.448445
# [t-SNE] Error after 125 iterations: 0.448445

# %%
tsne_results.shape
# Out:
# (891L, 2L)

# %%
plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y, cmap=plt.cm.Spectral, s = 10)
plt.show()

# %% [markdown]
# In the t-SNE, I attempted to tune learning rate and perplexity, but the default parameters gave the lowest value of KL Divergence, so this is the one I used to plot the data. With this, I am able to get some separation in the regions for survived and not survived, but overall the separation is not very good. We could not obtain a good separation of the two datasets.

# %% [markdown]
# ### Predictions on test data

# %% [markdown]
# Let's clean up the test dataset provided separately.
# Then we will run the classifier on the on test dataset (for which the actual survival status is not known. This is for the kaggle submission :)

# %%
data_test = pd.read_csv('test.csv')
data_test.head()
data_test.drop({"Cabin", "Name", "Ticket"}, axis = 1, inplace = True)
data_test.fillna(value = {"Embarked" : "S"}, inplace = True).head()
data_test.fillna(value = {"Age":29.699118, "Fare":35.627188}, inplace = True)
#pd.get_dummies(data[{"Sex", "Embarked"}])
print(data_test.isnull().sum())
data_test = pd.get_dummies(data_test, columns={"Sex", "Embarked"}, drop_first=True)
#normalize by the same parametesr as the test set, rather than min and max of the the test dataset. This is to retain the original feature scaling. 
data_test=(data_test-dataclean.min())/(dataclean.max()-dataclean.min())
#rearrange the columns. Test data has columns in a different order. 
cols = list(X_train.columns.values)
print(cols)
dataclean_test = data_test[cols]
dataclean_test.describe()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64
# ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_Q', 'Embarked_S', 'Sex_male']
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean      1.235393    0.632775    0.373644    0.055921    0.065391
# std       0.135742    0.420919    0.158792    0.112095    0.163571
# min       1.001124    0.000000   -0.003141    0.000000    0.000000
# 25%       1.118258    0.000000    0.283740    0.000000    0.000000
# 50%       1.235393    1.000000    0.367921    0.000000    0.000000
# 75%       1.352528    1.000000    0.443956    0.125000    0.000000
# max       1.469663    1.000000    0.949736    1.000000    1.500000
#
#              Fare  Embarked_Q  Embarked_S    Sex_male
# ...

# %%
logistic_reg_best = LogisticRegression(C = 1)
fit = logistic_reg_best.fit(X_train, y_train)
print(fit.score(X_test, y_test))
print(classification_report(y_test, logistic_reg.predict(X_test)))
prediction = logistic_reg_best.predict(dataclean_test)
# Out:
# 0.813432835821
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.88      0.85       165
#         1.0       0.79      0.68      0.73       103
#
# avg / total       0.80      0.81      0.80       268

# %%
prediction.shape
df = pd.DataFrame.from_items([("Survived", prediction)])

# %%
data_test = pd.read_csv('test.csv')
test_results = pd.concat([data_test["PassengerId"], df], axis = 1)

# %%
test_results.head()
# Out:
#    PassengerId  Survived
# 0          892       0.0
# 1          893       0.0
# 2          894       0.0
# 3          895       0.0
# 4          896       1.0

# %%
test_results.to_csv("submission.csv")
